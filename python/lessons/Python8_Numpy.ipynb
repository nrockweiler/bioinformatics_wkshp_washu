# %% [markdown]
# # Scientific Python: NumPy, SciPy, and Matplotlib
#
# ## Why NumPy and SciPy?
#
# The basic operations used in scientific programming include arrays, matrices, integration, differential equation solvers, statistics, and much more. Python, by default, does not have any of these functionalities built in, except for some basic mathematical operations that can only deal with a variable and not an array or matrix. NumPy and SciPy are two powerful Python packages, however, that enable the language to be used efficiently for scientific purposes.
#
# **NumPy** specializes in numerical processing through multi-dimensional **ndarrays**, where the arrays allow element-by-element operations. The arrays can be modified in size dynamically. This takes out the worries that usually mire quick programming in other languages. Rather than creating a new array when you want to get rid of certain elements, you can apply a mask to it.
#
# **SciPy** is built on the NumPy array framework and takes scientific programming to a whole new level by supplying advanced mathematical functions like *integration, ordinary differential equation solvers, special functions, optimizations, and more*.
#
# #### These are very powerful packages, we will just scratch the surface!
#
# ## Let's analyze some data
#
# We are going to use numpy and scipy to analyze data based on the famous 1885 study of Francis Galton exploring the relationship between the heights of children and the height of their parents. The variables are the height of the adult child in the first column and the midparent height in the second column, defined as the average of the height of the father and 1.08 times the height of the mother. The units are inches. The number of cases is 928, representing 928 children and their 205 parents. You can get it here:
#
#     wget https://genomic.wustl.edu/bioinformatics/python/lessons/Galton.txt
#
# First, let's import the NumPy package. Often, NumPy is imported as np:
#
#     >>> import numpy as np
#
# Next, let's import the data using the `.loadtxt()` function from the NumPy package. The first paramter is the name of the file, the second parameter is specifying that we want to skip the first row or the header, and the last parameter specifies that the tab character (\t) is what separates values on a row:
#
#     >>> galton = np.loadtxt("Galton.txt", skiprows=1,delimiter="\t")
#     >>> galton
#         array([[ 61.7,  70.5],
#                [ 61.7,  68.5],
#                [ 61.7,  65.5],
#                ...,
#                [ 73.7,  69.5],
#                [ 73.7,  69.5],
#                [ 73.7,  69.5]])
#
# Let's find the average height of the children and their parents:
#
#     >>> np.average(galton,axis=0)
#     array([ 68.08846983,  68.30818966])
#
# Here, we passed the galton numpy **ndarray** to the function as well as the axis that we want to analyze. Here we want to perform this analysis along the columns (representing the children in column 1 and the parents in column 2), which is axis=0.
#
# What would happen if we didn't tell it which axis?
#
#     >>> np.average(galton)
#     68.198329741378316
#
# It averages all the values in the ndarray. Here is a description outlining the anatomy of an array:
#
# <img src="numpyaxis.png" width="600">
#
#
# We can do the same thing with variance:
#
#     >>> np.var(galton,axis=0)
#     array([ 6.3331968 ,  3.19111827])
#
# What about if we want to calculate the correlation between child adult height and their parent's height? Let's calculate the Pearson correlation between the child adult heights and the mid-parent height. To perform statistics on a NumPy array, we will used the **SciPy stats module**, which is built upon the data structures from NumPy:
#
#     >>> from scipy import stats
#
# Before we can calculate the Pearson correlation, however, we should make sure that height comes from a normal distribution.
#
#     >>> stats.normaltest(galton)
#     (array([ 7.45230874,  0.4149256 ]), array([ 0.02408528,  0.81264347])):
#
# This function tests the null hypothesis that a sample comes from a normal distribution and returns two values for every test, the second of which is the p-value for the hypothesis test. Here, both p-values for the two different height distributions are >0.05 and we failed to reject the null hypothesis. We can, therefore, move forward with correlation calculation. For this, we will use the funciton `corrcoef()` from the NumPy package to calculate the Pearson correlation coefficient:
#
#     >>> np.corrcoef(np.transpose(galton))
#     array([[ 1.        ,  0.45876237],
#            [ 0.45876237,  1.        ]])
#
# Let's take it a step further and use the **SciPy stats module** again to perform linear regression.
#
# Now, let's perform linear regression using the `linregress()` function:
#
#     >>> stats.linregress(galton)
#     (0.32564749731059761, 46.135349860111184, 0.45876236829282202, 1.7325092920159686e-49, 0.020727204563501286)
#
# What is this function returning? **Let's look at the help:**
#     >>> help(stats.linregress)
#     Help on function linregress in module scipy.stats.stats:
#
#     linregress(x, y=None)
#     Calculate a regression line
#
#     This computes a least-squares regression for two sets of measurements.
#
#     Parameters
#     ----------
#     x, y : array_like
#         two sets of measurements.  Both arrays should have the same length.
#         If only x is given (and y=None), then it must be a two-dimensional
#         array where one dimension has length 2.  The two sets of measurements
#         are then found by splitting the array along the length-2 dimension.
#
#     Returns
#     -------
#     slope : float
#         slope of the regression line
#     intercept : float
#         intercept of the regression line
#     r-value : float
#         correlation coefficient
#     p-value : float
#         two-sided p-value for a hypothesis test whose null hypothesis is
#         that the slope is zero.
#     stderr : float
#         Standard error of the estimate
#
# Here, we find that `P<0.001`, so the slope of the linear regression is significantly different that 0 and there is a signficant correlation between the adult children and mid-parent's heights.
#
# What I've shown you is just barely scratching the surface of the statstical tests that you can perform using SciPy/NumPy. [Here](http://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html) is complete list of the functions available in the stats module.
#
#
# # You Try
#
# The most common nonparametric test for a difference in mean expression is the **Wilcoxon rank-sum test**, which is also known as the Mann-Whitney test.
#
# You have RNA-seq expression data for your favorite gene, YFG, across a control and treatment group. You want
