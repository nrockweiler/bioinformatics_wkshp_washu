# %% [markdown]
# #Making choices
#
# Often we want to check if a condition is true and take one action if it is, and another action if the
# condition is false. We can achieve this in Python with an **if statement**.
#
# __TIP:__ You can use any expression that returns a boolean value (`True` or `False`) in an `if` statement.
# Common boolean operators are:
#
# Operator | Description
# :---: | ---
# `==` | Equal to
# `!=` | Not equal to
# `<` | Less than
# `<=` | Less then or equal to
# `>` | Greater than
# `>=`| Greater than or equal to
#
# You can also use `is` and `is not` if you want to
# check if two variables are identical in the sense that they are stored in the same location in memory.
#
# * The syntax of an `if` statement is:
#
#         if condition:
#             # Do something if the condition is true
#   The first line starts with the keyword `if` followed by a conditional statement. The conditional statement is a statement that evaulates to true or false, e.g., `0 < 1`. The first line ends in a `:`. Every indented statement after the `if` declaration is part of the `if` code block.
#
#
# * Example of a simple `if` statement:
#         >>> x = -1
#         >>> if x > 0:
#         ...     print('x is positive')
#
# * `If` statements can rely on boolean variables
#         >>> test = (x > 0)
#         >>> print(type(test))
#         >>> print(test)
#         >>> if test:
#         ...     print('Test was true')
#
# * Things can get pretty boring if we can only use `if`.  A close cousin to `if` is **`else`**.  An `else` statement is evaluated when the if statement is false.  The syntax is:
#
#         if condition:
#             # Do something if the condition is true
#         else:
#             # Do something if the condition is false
#   The `else` statement comes after the `if` code block.  The line ends in a `:`.  Notice that the `else` keyword is at the same indentation level as the `if` keyword. Every indented statement after the `else` declaration is part of the `else` code block.
#
#
# * Example of a simple `if`/`else` statement:
#         >>> if x > 0:
#         ...     print('x is positive')
#         ... else:
#         ...     print('x is not positive')
#
# * Another close cousin is **`elif`** (short for "else if").  An `elif` statement is evaluated when the `if` statement is false *and* the `elif` statement is true.  The syntax is:
#
#         if condition1:
#             # Do something if condition1 is true
#         elif condition2:
#             # Do something if condition1 is true AND condition2 is true
#   The `elif` statement comes after the `if` code block.  The line ends in a `:`.  Like before, the `elif` keyword is at the same indentation level as the `if` keyword. Every indented statement after the `elif` declaration is part of the `elif` code block.
#
#
# * You can get pretty crazy and add multiple `elif` statements. **Note:** Python will evaluate the conditional statements *in the order that they appear in the code* so you must be careful how you order them.  This is also why there can only be one `else` statement in the code block and it must appear at the end.
#
#
# * Example of a simple `if`/`elif`/`else` statement:
#         >>> if x > 0:
#         ...     print('x is positive')
#         ... elif x < 0:
#         ...     print('x is negative')
#         ... else:
#         ...     print('x is zero')
#
#
# ## What does Python consider True/False?
#
# A false value doesn’t necessarily need to explicitly be False. For example, **these are all considered False**:
#
# name | value
# --- | ---
# boolean | False
# null | None
# zero integer | 0
# zero float | 0.0
# empty string | ''
# empty list | []
# empty tuple | ()
# empty dict | {}
#
#
# #You Try
#
# We often ask questions about our analysis or results. We can do this with conditionals. Perform these calculations in the script that you created (`analyze_heights.py`). Before continuing, remove all previous print statements from [your script](https://genomic.wustl.edu/bioinformatics/python/lessons/analyze_heights-solution2.py) while leaving all other variables and lists.
#
# 1. Test whether `variance` is larger than `0.01`, and print out a line that says "variance more than 0.01: "
# followed by the answer (either True or False).
# 2. Test whether the `mean` and the `variance` are approximately equal, or follow a Poisson distribution, within some threshold (`0.01`). To do this, test if the absolute value of the difference between the mean and variance is less than `0.01` and print out a line that says "The mean and the variance are approximately equal: " followed by the answer (either True or False).
#
# **Note:** The built-in function for absolute value in Python is **`abs()`**
#
# <img src="stopgo.jpeg" width="100" >
